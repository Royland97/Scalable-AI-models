# %%
from pyspark.sql import SparkSession

#Crear una sesión de Spark
spark = (SparkSession.builder
    .appName('KNN Escalable')
    .master("local[*]")
    .getOrCreate())

spark.sparkContext.setLogLevel('WARN')
print("Spark: "+spark.version)
# Out:
# Spark: 3.5.1

# %% [markdown]
# Load Dataset

# %%
from pyspark import SparkFiles
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType

#Crear el esquema
schema = StructType([
    StructField("Size",DoubleType(),True),
    StructField("Weight",IntegerType(),True),
    StructField("Brix",DoubleType(),True),
    StructField("pH",DoubleType(),True),
    StructField("Softness",DoubleType(),True),
    StructField("HarvestTime",IntegerType(),True),
    StructField("Ripeness",DoubleType(),True),
    StructField("Color",StringType(),True),
    StructField("Variety",StringType(),True),
    StructField("Blemishes",StringType(),True),
    StructField("Quality",DoubleType(),True),
])

spark.sparkContext.addFile("https://raw.githubusercontent.com/Royland97/dataset/main/orange.csv")
df = spark.read.schema(schema).csv(SparkFiles.get("orange.csv"), header=True, inferSchema=True)
df.printSchema()
df.show()
# Out:
# root
#  |-- Size: double (nullable = true)
#  |-- Weight: integer (nullable = true)
#  |-- Brix: double (nullable = true)
#  |-- pH: double (nullable = true)
#  |-- Softness: double (nullable = true)
#  |-- HarvestTime: integer (nullable = true)
#  |-- Ripeness: double (nullable = true)
#  |-- Color: string (nullable = true)
#  |-- Variety: string (nullable = true)
#  |-- Blemishes: string (nullable = true)
#  |-- Quality: double (nullable = true)
#
# +----+------+----+---+--------+-----------+--------+-------------+----------------+-------------+-------+
# |Size|Weight|Brix| pH|Softness|HarvestTime|Ripeness|        Color|         Variety|    Blemishes|Quality|
# +----+------+----+---+--------+-----------+--------+-------------+----------------+-------------+-------+
# | 7.5|   180|12.0|3.2|     2.0|         10|     4.0|       Orange|        Valencia|            N|    4.0|
# | 8.2|   220|10.5|3.4|     3.0|         14|     4.5|  Deep Orange|           Navel|            N|    4.5|
# | 6.8|   150|14.0|3.0|     1.0|          7|     5.0| Light Orange|       Cara Cara|            N|    5.0|
# | 9.0|   250| 8.5|3.8|     4.0|         21|     3.5|   Orange-Red|    Blood Orange|            N|    3.5|
# | 8.5|   210|11.5|3.3|     2.5|         12|     5.0|       Orange|          Hamlin|    Y (Minor)|    4.5|
# | 6.7|   126| 9.1|3.0|     2.0|         25|     2.0|       Orange|           Navel|            N|    1.0|
# | 7.2|   160| 9.0|3.5|     3.5|          9|     4.0|Yellow-Orange|Tangelo (Hybrid)|            N|    4.0|
# | 6.5|   130|13.5|2.8|     1.5|          5|     4.5| Light Orange|Murcott (Hybrid)|            N|    4.5|
# | 8.8|   240| 7.5|4.0|     5.0|         18|     3.0|  Deep Orange|    Moro (Blood)|  Y (Sunburn)|    3.0|
# | 7.8|   190|12.0|3.1|     2.0|         11|     4.5|       Orange|           Jaffa|            N|    5.0|
# | 9.5|   270| 6.0|4.2|     4.5|         24|     2.5|   Orange-Red|       Cara Cara|Y (Mold Spot)|    2.5|
# | 7.8|   183|14.8|3.7|     2.0|         12|     3.0|  Deep Orange|        Valencia|Y (Mold Spot)|    4.0|
# | 8.0|   200|10.0|3.5|     3.0|         13|     4.0|       Orange|      Clementine|            N|    4.5|
# | 7.0|   140|11.0|3.2|     2.5|          8|     4.5|  Deep Orange|Washington Navel|            N|    5.0|
# | 9.2|   260| 9.5|3.7|     4.5|         20|     4.0|   Orange-Red|       Star Ruby|            N|    4.0|
# | 6.3|   120|14.5|2.9|     1.0|          6|     5.0| Light Orange|       Tangerine|            N|    5.0|
# | 8.7|   230| 8.0|3.9|     3.5|         17|     3.5|       Orange|        Ambiance|   Y (Bruise)|    3.5|
# | 9.6|   218|14.1|4.2|     4.0|         11|     1.0|  Deep Orange|       Cara Cara|  Y (Sunburn)|    4.0|
# | 7.5|   247| 9.1|3.3|     4.0|         24|     5.0| Light Orange|      Clementine|            N|    2.0|
# | 7.4|   170|12.5|3.0|     2.0|         10|     4.0|Yellow-Orange|           Jaffa|            N|    4.5|
# +----+------+----+---+--------+-----------+--------+-------------+----------------+-------------+-------+
# only showing top 20 rows

# %% [markdown]
# Data

# %%
df = df.select("Weight","Variety")
rdd = df.rdd.map(lambda row: (row["Weight"],row["Variety"]))
rdd.collect()
# Out:
# [(180, 'Valencia'),
#  (220, 'Navel'),
#  (150, 'Cara Cara'),
#  (250, 'Blood Orange'),
#  (210, 'Hamlin'),
#  (126, 'Navel'),
#  (160, 'Tangelo (Hybrid)'),
#  (130, 'Murcott (Hybrid)'),
#  (240, 'Moro (Blood)'),
#  (190, 'Jaffa'),
#  (270, 'Cara Cara'),
#  (183, 'Valencia'),
#  (200, 'Clementine'),
#  (140, 'Washington Navel'),
#  (260, 'Star Ruby'),
#  (120, 'Tangerine'),
#  (230, 'Ambiance'),
#  (218, 'Cara Cara'),
#  (247, 'Clementine'),
#  (170, 'Jaffa'),
#  (300, 'Blood Orange'),
#  (205, 'Murcott (Hybrid)'),
#  (180, 'California Valencia'),
#  (280, 'Moro (Blood)'),
#  (190, 'Honey Tangerine'),
#  (215, 'Navel (Late Season)'),
#  (140, 'Clementine (Seedless)'),
#  (111, 'Cara Cara'),
#  (177, 'Temple'),
#  (240, 'Cara Cara'),
#  (220, 'Hamlin'),
#  (150, 'Minneola (Hybrid)'),
#  (185, 'Temple'),
#  (245, 'Moro (Blood)'),
#  (110, 'Satsuma Mandarin'),
#  (225, 'Midsweet (Hybrid)'),
#  (165, 'California Valencia'),
#  (285, 'Cara Cara'),
#  (200, 'Navel (Early Season)'),
#  (175, 'Ambiance'),
#  (260, 'Star Ruby'),
#  (125, 'Tangerine'),
#  (190, 'Ortanique (Hybrid)'),
#  (210, 'Washington Navel'),
#  (135, 'Clementine (Seedless)'),
#  (185, 'Jaffa'),
#  (240, 'Cara Cara'),
#  (215, 'Hamlin'),
#  (275, 'Moro (Blood)'),
#  (160, 'Temple'),
#  (230, 'Midsweet (Hybrid)'),
#  (105, 'Satsuma Mandarin'),
#  (220, 'California Valencia'),
#  (290, 'Cara Cara'),
#  (185, 'Navel (Early Season)'),
#  (170, 'Ambiance'),
#  (255, 'Star Ruby'),
#  (120, 'Tangerine'),
#  (180, 'Ortanique (Hybrid)'),
#  (205, 'Washington Navel'),
#  (130, 'Clementine (Seedless)'),
#  (235, 'Cara Cara'),
#  (200, 'Hamlin'),
#  (165, 'California Valencia'),
#  (240, 'Moro (Blood)'),
#  (140, 'Honey Tangerine'),
#  (215, 'Navel (Late Season)'),
#  (150, 'Minneola (Hybrid)'),
#  (280, 'Cara Cara'),
#  (190, 'Temple'),
#  (220, 'Midsweet (Hybrid)'),
#  (100, 'Satsuma Mandarin'),
#  (210, 'California Valencia'),
#  (175, 'Washington Navel'),
#  (270, 'Star Ruby'),
#  (135, 'Tangerine'),
#  (235, 'Cara Cara'),
#  (190, 'Hamlin'),
#  (225, 'Murcott (Hybrid)'),
#  (145, 'Minneola (Hybrid)'),
#  (250, 'Moro (Blood)'),
#  (115, 'Clementine (Seedless)'),
#  (210, 'Navel (Late Season)'),
#  (185, 'Temple'),
#  (240, 'Midsweet (Hybrid)'),
#  (140, 'Honey Tangerine'),
#  (200, 'California Valencia'),
#  (170, 'Washington Navel'),
#  (205, 'Ambiance'),
#  (160, 'Ortanique (Hybrid)'),
#  (280, 'Cara Cara'),
#  (130, 'Tangerine'),
#  (230, 'Moro (Blood)'),
#  (190, 'Temple'),
#  (210, 'California Valencia'),
#  (120, 'Satsuma Mandarin'),
#  (115, 'Jaffa'),
#  (220, 'Midsweet (Hybrid)'),
#  (150, 'Minneola (Hybrid)'),
#  (158, 'Clementine'),
#  (192, 'Navel'),
#  (127, 'Honey Tangerine'),
#  (118, 'Valencia'),
#  (220, 'Clementine'),
#  (202, 'Cara Cara'),
#  (130, 'Jaffa'),
#  (123, 'Clementine'),
#  (143, 'Washington Navel'),
#  (269, 'Star Ruby'),
#  (120, 'Cara Cara'),
#  (152, 'Navel'),
#  (270, 'Navel'),
#  (184, 'Ambiance'),
#  (137, 'Ortanique (Hybrid)'),
#  (236, 'Temple'),
#  (279, 'Navel'),
#  (293, 'Temple'),
#  (209, 'Star Ruby'),
#  (246, 'Cara Cara'),
#  (253, 'Satsuma Mandarin'),
#  (298, 'Temple'),
#  (169, 'Ambiance'),
#  (260, 'Satsuma Mandarin'),
#  (252, 'Minneola (Hybrid)'),
#  (297, 'Cara Cara'),
#  (243, 'Honey Tangerine'),
#  (108, 'Minneola (Hybrid)'),
#  (117, 'Moro (Blood)'),
#  (234, 'Ortanique (Hybrid)'),
#  (276, 'Ortanique (Hybrid)'),
#  (269, 'Moro (Blood)'),
#  (234, 'Honey Tangerine'),
#  (155, 'Navel'),
#  (198, 'Navel'),
#  (298, 'Star Ruby'),
#  (122, 'Washington Navel'),
#  (293, 'Moro (Blood)'),
#  (143, 'Star Ruby'),
#  (257, 'Ortanique (Hybrid)'),
#  (157, 'Ortanique (Hybrid)'),
#  (180, 'Ambiance'),
#  (177, 'Clementine'),
#  (296, 'Temple'),
#  (187, 'Valencia'),
#  (129, 'Tangerine'),
#  (292, 'Washington Navel'),
#  (281, 'Jaffa'),
#  (222, 'Washington Navel'),
#  (139, 'Tangerine'),
#  (234, 'Temple'),
#  (238, 'Tangerine'),
#  (264, 'Valencia'),
#  (217, 'Moro (Blood)'),
#  (294, 'Navel'),
#  (206, 'Navel'),
#  (274, 'Temple'),
#  (298, 'Clementine'),
#  (126, 'Washington Navel'),
#  (168, 'Clementine'),
#  (246, 'Cara Cara'),
#  (250, 'Valencia'),
#  (106, 'Jaffa'),
#  (141, 'Valencia'),
#  (126, 'Navel'),
#  (176, 'Cara Cara'),
#  (256, 'Satsuma Mandarin'),
#  (127, 'Star Ruby'),
#  (151, 'Moro (Blood)'),
#  (258, 'Temple'),
#  (179, 'Ambiance'),
#  (288, 'Jaffa'),
#  (236, 'Ambiance'),
#  (139, 'Moro (Blood)'),
#  (263, 'Navel'),
#  (204, 'Temple'),
#  (292, 'Jaffa'),
#  (269, 'Valencia'),
#  (143, 'Clementine'),
#  (129, 'Tangerine'),
#  (291, 'Satsuma Mandarin'),
#  (198, 'Cara Cara'),
#  (259, 'Ortanique (Hybrid)'),
#  (171, 'Jaffa'),
#  (182, 'Star Ruby'),
#  (112, 'Washington Navel'),
#  (217, 'Washington Navel'),
#  (245, 'Satsuma Mandarin'),
#  (273, 'Tangerine'),
#  (225, 'Honey Tangerine'),
#  (165, 'Star Ruby'),
#  (285, 'Satsuma Mandarin'),
#  (283, 'Star Ruby'),
#  (192, 'Navel'),
#  (264, 'Star Ruby'),
#  (195, 'Star Ruby'),
#  (141, 'Ortanique (Hybrid)'),
#  (246, 'Satsuma Mandarin'),
#  (261, 'Temple'),
#  (193, 'Star Ruby'),
#  (288, 'Washington Navel'),
#  (277, 'Clementine'),
#  (296, 'Tangerine'),
#  (299, 'Clementine'),
#  (162, 'Minneola (Hybrid)'),
#  (142, 'Valencia'),
#  (138, 'Navel'),
#  (128, 'Ortanique (Hybrid)'),
#  (169, 'Washington Navel'),
#  (197, 'Temple'),
#  (187, 'Tangerine'),
#  (298, 'Clementine'),
#  (149, 'Minneola (Hybrid)'),
#  (237, 'Minneola (Hybrid)'),
#  (146, 'Ortanique (Hybrid)'),
#  (233, 'Satsuma Mandarin'),
#  (248, 'Cara Cara'),
#  (261, 'Valencia'),
#  (228, 'Ortanique (Hybrid)'),
#  (130, 'Temple'),
#  (267, 'Star Ruby'),
#  (280, 'Minneola (Hybrid)'),
#  (246, 'Minneola (Hybrid)'),
#  (291, 'Clementine'),
#  (276, 'Star Ruby'),
#  (210, 'Navel'),
#  (261, 'Ambiance'),
#  (100, 'Satsuma Mandarin'),
#  (265, 'Moro (Blood)'),
#  (189, 'Ambiance'),
#  (202, 'Cara Cara'),
#  (147, 'Moro (Blood)'),
#  (131, 'Star Ruby'),
#  (273, 'Navel'),
#  (249, 'Tangerine'),
#  (251, 'Clementine'),
#  (130, 'Valencia'),
#  (194, 'Tangerine'),
#  (275, 'Minneola (Hybrid)'),
#  (196, 'Temple'),
#  (251, 'Moro (Blood)'),
#  (282, 'Jaffa')]

# %% [markdown]
# KNN Escalable

# %%
import numpy as np

def distancia(x1, x2):
    return float(np.sqrt(np.sum((x1 - x2) ** 2)))

xample = 230
k = 10

rdd_distancia = rdd.map(lambda x: (distancia(x[0], xample), x[1]))

k_vecinos = rdd_distancia.sortByKey(lambda x: x[0]).take(k)
rdd_vecinos = spark.sparkContext.parallelize(k_vecinos)

label_count = (rdd_vecinos
           .map(lambda x: (x[1], 1))
           .reduceByKey(lambda a, b: a + b))

variety = label_count.sortBy(lambda x: x[1]).first()[0]
print("Variety: " + variety)
# Out:
# Variety: Honey Tangerine
